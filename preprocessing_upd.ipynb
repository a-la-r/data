# %%
import pandas as pd
import numpy as np

# %%
path = './csv datasets/'

# %%
df_kak_wr = pd.read_csv(path + 'df_kak_wr.csv')
df_slovno_wr = pd.read_csv(path + 'df_slovno_wr.csv')
df_aki_wr = pd.read_csv(path + 'df_aki_wr.csv')
df_ala_wr = pd.read_csv(path + 'df_ala_wr.csv')
df_budto_wr = pd.read_csv(path + 'df_budto_wr.csv')
df_podobno_wr = pd.read_csv(path + 'df_podobno_wr.csv')

# %%
df_kak_250 = df_kak_wr.sample(n=250)
df_slovno_250 = df_slovno_wr.sample(n=250)
df_aki_250 = df_aki_wr.sample(n=250)
df_ala_250 = df_ala_wr.sample(n=250)
df_budto_250 = df_budto_wr.sample(n=250)
df_podobno_250 = df_podobno_wr.sample(n=250)

# %%
frames = [df_kak_250, df_slovno_250, df_aki_250, df_ala_250, df_budto_250, df_podobno_250]
df_250_wr = pd.concat(frames)

# %%
df_250_wr = df_250_wr.reset_index(drop=True)

# %%
df_250_wr
# Out:
#                                     Left context     Center  \
# 0       перенести чертеж на бумагу ― отпечатать,       как
# 1                  Левитан в приемной вели себя,       как
# 2           величества интереса, вреде и убытке,       как
# 3                                 Не оставили Мы      какъ
# 4     орфографию и законы пунктуации чувствовал,       как
# ...                                          ...        ...
# 1495                  и быть изолирована от нее.   Подобно
# 1496              людей, картечь прыгая по земле   подобно
# 1497           примерное рвение к наукам, успел,   подобно
# 1498   установкой» ― это всегда « установка на…»   подобно
# 1499      политической партии, которая могла бы,   подобно
#
#                                        Right context    Created  \
# 0                             фотоснимок с негатива.  1940-1956
# 1                                         школьники.       1915
# ...

# %%
for i, text in enumerate(df_250_wr['Sphere']):
    df_250_wr['Sphere'][i] = text.split(',')[0]

# %%
for i, text in enumerate(df_250_wr['Sphere']):
    if df_250_wr['Sphere'][i] == 'бытовая':
        df_250_wr['Sphere'][i] = 'нехудожественная'
    elif df_250_wr['Sphere'][i] == 'художественная проза':
        df_250_wr['Sphere'][i] = 'художественная'
    elif df_250_wr['Sphere'][i] == 'публицистика':
        df_250_wr['Sphere'][i] = 'нехудожественная'

# %%
for i, text in enumerate(df_250_wr['Type']):
     df_250_wr['Type'][i] = text.split(',')[0]

# %%
for i, text in enumerate(df_250_wr['Center']):
    df_250_wr['Center'][i] = text.lower()

# %%
for i, text in enumerate(df_250_wr['Left context']):
    try:
        df_250_wr['Left context'][i] = text.lower()
    except:
        continue

# %%
for i, text in enumerate(df_250_wr['Right context']):
    try:
        df_250_wr['Right context'][i] = text.lower()
    except:
        continue

# %%
for i, text in enumerate(df_250_wr['Created']):
    if len(text) == 4:
        text = list(text)
        text[3] = str(0) 
        text = "".join(text)
        #print(text)
        df_250_wr['Created'][i] = text
    else:
        text = text[:4]
        df_250_wr['Created'][i] = text

# %%
for i, text in enumerate(df_250_wr['Center']):
    if df_250_wr['Center'][i] == ' какъ ':
        df_250_wr['Center'][i] = ' как '

# %%
df_250_wr.head(20)
# Out:
#                                   Left context Center  \
# 0     перенести чертеж на бумагу ― отпечатать,   как
# 1                левитан в приемной вели себя,   как
# 2         величества интереса, вреде и убытке,   как
# 3                               не оставили мы   как
# 4   орфографию и законы пунктуации чувствовал,   как
# 5                        я совершенно не знаю,   как
# 6                 не есть течение в искусстве,   как
# 7                             дискуссии о том,   как
# 8       что за замечательный писатель толстой,   как
# 9                  узнал, что ничего нет хуже,   как
# 10         исходном положении погрузить в воду   как
# 11                                   на защите   как
# 12                очевидно также, что до того,   как
# 13                    все равно будет при них,   как
# 14                разруха росли с каждым днем.   как
# 15                                  в чем же и   как
# 16                  не зналъ, на что рѣшиться,   как
# ...

# %%
for i, text in enumerate(df_250_wr['Center']):
    text = text.strip(' ')
    df_250_wr['Center'][i] = text

# %%
df_250_wr['Center'][1499]
# Out:
# 'подобно'

# %%
df_250_wr.to_csv(r'./df_250_wr.csv', encoding='utf-8', index = False, sep=';')

# %% [markdown]
# ### чтение

# %%
df_250_wr = pd.read_csv(r'./df_250_wr.csv', encoding='utf-8', sep=';')

# %%
df_250_wr.head(10)
# Out:
#                                  Left context Center  \
# 0    перенести чертеж на бумагу ― отпечатать,    как
# 1               левитан в приемной вели себя,    как
# 2        величества интереса, вреде и убытке,    как
# 3                              не оставили мы    как
# 4  орфографию и законы пунктуации чувствовал,    как
# 5                       я совершенно не знаю,    как
# 6                не есть течение в искусстве,    как
# 7                            дискуссии о том,    как
# 8      что за замечательный писатель толстой,    как
# 9                 узнал, что ничего нет хуже,    как
#
#                                     Right context  Created            Sphere  \
# 0                          фотоснимок с негатива.     1940    художественная
# 1                                      школьники.     1910  нехудожественная
# 2                   скоро о том уведаю, не токмо      1720  нехудожественная
# ...

# %%
#date_list = df_250_wr['Created'].unique().tolist()
#print(date_list)
# Out:
# [1930, 1900, 1920, 1910, 1940, 1890, 1950, 1960, 2000, 1970, 1980, 1990, 2010, 1760, 1860, 1750, 1850, 1830, 1880, 1720, 1840, 1780, 1790, 1710, 1700, 1810, 1870, 1800, 1770, 1820]

# %%
""""
first = [1700, 1710, 1720, 1730, 1740]
second = [1750, 1760, 1770, 1780, 1790]
third = [1800, 1810, 1820, 1830, 1840]
fourth = [1850, 1860, 1870, 1880, 1890]
fifth = [1900, 1910, 1920, 1930, 1940]
sixth = [1950, 1960, 1970, 1980, 1990]
seventh = [2000, 2010]

for i, date in enumerate(df_250_wr['Created']):
    if date in first:
        df_250_wr['Created'][i] = '1700-1750'
    elif date in second:
        df_250_wr['Created'][i] = '1750-1800'
    elif date in third:
        df_250_wr['Created'][i] = '1800-1850'
    elif date in fourth:
        df_250_wr['Created'][i] = '1850-1900'
    elif date in fifth:
        df_250_wr['Created'][i] = '1900-1950'
    elif date in sixth:
        df_250_wr['Created'][i] = '1950-2000'
    elif date in seventh:
        df_250_wr['Created'][i] = '2000-2020'
""""
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\User\Anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_250_wr['Type'].unique().tolist()
# Out:
# ['художественный', 'публицистический', 'деловой', 'научный', 'разговорный']

# %% [markdown]
# 1) научный - монография, учебное пособие, учебник, лекция
# 2) деловой - отчет, записка докладная, устав, послание?,
# 3) публицистический - фельетон, репортаж, статья, очерк, дневник?, мемуары?, доклад?, эссе,
# предисловие, рецензия, отзыв, анонс?, катехизис?, трактат, обзор, блог, комментарий, интервью, заметка, записки?, биография,
# гороскоп, информационное сообщение
# 4) художественный - рассказ, роман, повесть, сказ, сказка, пьеса, миниатюра, анекдот?, легенда, цикл
# 5) разговорный - беседа, письмо личное, речь, слово, проповедь?, поучение, форум
# 6) _

# %%
science = ['монография', 'учебное пособие', 'учебник', 'лекция']
business = ['отчет', 'записка докладная', 'устав', 'анкета', 'письмо деловое', 'послание', 'закон', 'обращение', 'указ', 'манифест', 'инструкция', 'соглашение','приказ', 'предписание', 'объявление' ]
bookish = ['фельетон', 'репортаж', 'статья','рассуждение', 'очерк', 'автобиография', 'дневник', 'мемуары', 'доклад', 'эссе', 'предисловие', 'рецензия', 
           'отзыв', 'анонс', 'катехизис', 'трактат', 'обзор', 'блог', 'комментарий', 'интервью', 'заметка', 'записки', 
           'биография', 'гороскоп', 'информационное сообщение']
fiction = ['рассказ', '_', 'письмо литературное','отрывок', 'роман', 'повесть', 'сказ', 'сказка', 'пьеса', 'миниатюра', 'анекдот', 'легенда', 'цикл', 'стихи', 'отрывки']
oral = ['беседа', 'письмо личное', 'речь', 'слово', 'проповедь', 'поучение', 'форум', 'письмо', 'наставление', 'интернет-пейджер']

for i, text in enumerate(df_250_wr['Type']):
    if text in science:
        df_250_wr['Type'][i] = 'научный'
    elif text in business:
        df_250_wr['Type'][i] = 'деловой'
    elif text in bookish:
        df_250_wr['Type'][i] = 'публицистический'
    elif text in fiction:
        df_250_wr['Type'][i] = 'художественный'
    elif text in oral: 
        df_250_wr['Type'][i] = 'разговорный'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
for i, text in enumerate(df_250_wr['Type']):
    if df_250_wr['Type'][i] == '_':
        print(df_250_wr['Full context'][i])
# Out:
# Но стоило ему оказаться дома одному, как он словно стервенел. [А. В. Рондарёв. Беседы о прекрасном // «Знамя» №2, 1996] [омонимия не снята]
# Когда отсыревшие куски старых досок разгорелись, он сел на траву, подогнув под себя ноги, и застыл, подобно индейцу. [А. В. Рондарёв. Беседы о прекрасном // «Знамя» №2, 1996] [омонимия не снята]

# %%
df_250_wr
# Out:
#                                     Left context   Center  \
# 0       перенести чертеж на бумагу ― отпечатать,      как
# 1                  левитан в приемной вели себя,      как
# 2           величества интереса, вреде и убытке,      как
# 3                                 не оставили мы      как
# 4     орфографию и законы пунктуации чувствовал,      как
# ...                                          ...      ...
# 1495                  и быть изолирована от нее.  подобно
# 1496              людей, картечь прыгая по земле  подобно
# 1497           примерное рвение к наукам, успел,  подобно
# 1498   установкой» ― это всегда « установка на…»  подобно
# 1499      политической партии, которая могла бы,  подобно
#
#                                        Right context  Created  \
# 0                             фотоснимок с негатива.     1940
# 1                                         школьники.     1910
# 2                      скоро о том уведаю, не токмо      1720
# ...

# %%
pos_list1 = df_250_wr['Left_context_POS'].unique().tolist()
print(pos_list1)
# Out:
# ['VERB', 'NPRO', 'NOUN', 'ADJ', 'ADVB', 'AUX', 'NUMR', 'TRSH', 'LATN', nan, 'PRT_GRND']

# %%
pos_list2 = df_250_wr['Right_context_POS'].unique().tolist()
print(pos_list2)
# Out:
# ['NOUN', 'ADVB', 'UNKN', 'NPRO', 'VERB', 'INFN', 'PRED', 'ADJS', 'PRCL', 'ADJF', 'PREP', 'PRTF', 'CONJ', 'NUMR', nan, 'GRND', 'PRTS', 'LATN', 'NUMB', 'COMP']

# %%
pos_list = pos_list1 + pos_list2
pos_list = set(pos_list)
print(pos_list)
print(len(pos_list))
# Out:
# {nan, 'GRND', 'PRT_GRND', 'ADJ', 'ADVB', 'AUX', 'NUMR', 'LATN', 'ADJF', 'NOUN', 'UNKN', 'NPRO', 'COMP', 'PRTS', 'INFN', 'ADJS', 'NUMB', 'PRCL', 'TRSH', 'CONJ', 'PRTF', 'PRED', 'PREP', 'VERB'}
# 24

# %% [markdown]
# 1) ADJ - ADJF, ADJS, COMP
# 2) AUX - PREP, CONJ, PRCL
# 3) TRSH - nan, UNKN, PNCT, INTJ, PRED
# 4) LATN
# 5) VERB - INFN, VERB
# 6) NOUN
# 7) PRT_GRND - PRTS, PRTF, GRND
# 8) NUMR - NUMB, NUMR
# 9) ADVB
# 10) NPRO

# %%
adj = ['ADJF', 'ADJS', 'COMP']
aux = ['PREP', 'CONJ', 'PRCL']
trsh = ['NaN', 'UNKN', 'PNCT', 'INTJ', 'PRED']
verb = ['INFN', 'VERB']
prt_grnd = ['PRTS', 'PRTF', 'GRND']
numr = ['NUMB', 'NUMR']

for i, text in enumerate(df_250_wr['Left_context_POS']):
    if text in adj:
        df_250_wr['Left_context_POS'][i] = 'ADJ'
    elif text in aux:
        df_250_wr['Left_context_POS'][i] = 'AUX'
    elif text in trsh:
        df_250_wr['Left_context_POS'][i] = 'TRSH'
    elif text in verb:
        df_250_wr['Left_context_POS'][i] = 'VERB'
    elif text in prt_grnd:
        df_250_wr['Left_context_POS'][i] = 'PRT_GRND'
    elif text in numr:
        df_250_wr['Left_context_POS'][i] = 'NUMR'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
for i, text in enumerate(df_250_wr['Right_context_POS']):
    if text in adj:
        df_250_wr['Right_context_POS'][i] = 'ADJ'
    elif text in aux:
        df_250_wr['Right_context_POS'][i] = 'AUX'
    elif text in trsh:
        df_250_wr['Right_context_POS'][i] = 'TRSH'
    elif text in verb:
        df_250_wr['Right_context_POS'][i] = 'VERB'
    elif text in prt_grnd:
        df_250_wr['Right_context_POS'][i] = 'PRT_GRND'
    elif text in numr:
        df_250_wr['Right_context_POS'][i] = 'NUMR'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df_250_wr['Left_context_POS'].replace(np.nan, 'TRSH', inplace=True)
df_250_wr['Right_context_POS'].replace(np.nan, 'TRSH', inplace=True)

# %%
df_250_wr.head(50)
# Out:
#                                      Left context Center  \
# 0        перенести чертеж на бумагу ― отпечатать,    как
# 1                   левитан в приемной вели себя,    как
# 2            величества интереса, вреде и убытке,    как
# 3                                  не оставили мы    как
# 4      орфографию и законы пунктуации чувствовал,    как
# 5                           я совершенно не знаю,    как
# 6                    не есть течение в искусстве,    как
# 7                                дискуссии о том,    как
# 8          что за замечательный писатель толстой,    как
# 9                     узнал, что ничего нет хуже,    как
# 10            исходном положении погрузить в воду    как
# 11                                      на защите    как
# 12                   очевидно также, что до того,    как
# 13                       все равно будет при них,    как
# 14                   разруха росли с каждым днем.    как
# ...

# %%
df_250_wr.to_csv(r'./df_250_wr.csv', encoding='utf-8', index = False, sep=';')

# %% [markdown]
# ##Устный корпус

# %%
df_kak_sp = pd.read_csv(path + 'df_kak_sp.csv')
df_slovno_sp = pd.read_csv(path + 'df_slovno_sp.csv')
df_aki_sp = pd.read_csv(path + 'df_aki_sp.csv')
df_ala_sp = pd.read_csv(path + 'df_ala_sp.csv')
df_budto_sp = pd.read_csv(path + 'df_budto_sp.csv')
df_podobno_sp = pd.read_csv(path + 'df_podobno_sp.csv')

# %%
df_podobno_sp.shape
# Out:
# (52, 9)

# %%
df_kak_250 = df_kak_wr.sample(n=250)
df_budto_250 = df_budto_wr.sample(n=250)

# %%
frames = [df_kak_250, df_slovno_sp, df_aki_sp, df_ala_sp, df_budto_250, df_podobno_sp]
df_sp = pd.concat(frames)

# %%
df_sp = df_sp.reset_index(drop=True)

# %%
df_sp = df_sp.drop(['Sphere'], axis=1)

# %%
df_sp
# Out:
#                                           Left context      Center  \
# 0                                Е́сть тако́е поня́тие        как
# 1                   Деви́ца Алекса́ндра зде́сь живёт /        Как
# 2                      ле́зет пе́ред дра́кой в ще́ли /        как
# 3                                Вы́ бы́ли для меня́ /       ка́к
# 4                         Ка́к зва́ть тебя́ / де́вица?       Ка́к
# ..                                                 ...         ...
# 761                      без тренировок / это ж смерти    подобно
# 762                              Паде́ние его́ сме́рти   подо́бно
# 763  пери́ода / а Ма́йкова засо́хшего / смо́рщившег...   подо́бно
# 764  сра́внивали / како́е коли́чество уча́стников п...   подо́бно
# 765      что́ большинство́ систе́м выбира́ет разме́тку   подо́бно
#
#                                          Right context Created  \
# 0    по́иски внеземны́х цивилиза́ций"― э́то вро́де бы     2010
# ...

# %%
for i, text in enumerate(df_sp['Type']):
    df_sp['Type'][i] = text.split(',')[0]
    if 'кино' in df_sp['Type'][i]:
        df_sp['Type'][i] = 'кино'

# %%
df_sp['Type'].unique().tolist()
# Out:
# ['научный', 'художественный', 'разговорный', 'публицистический', 'деловой']

# %%
science = ['лекция','доклад', 'семинар', 'конференция']
business = ['парламентские слушания']
publ = ['репортаж', 'комментарий', 'статья', 'интервью']
fiction = ['кино','рассказ', 'вестерн', 'радиопостановка', 'документально-художественная композиция', 'повесть', 'театральный спектакль']
oral = ['беседа', 'дискуссия', 'проповедь', 'встреча со слушателями', 'праздный', 'разговор при встрече', 'домашний', 'разговор']

# %%
for i, text in enumerate(df_sp['Type']):
    if text in science:
        df_sp['Type'][i] = 'научный'
    elif text in business:
        df_sp['Type'][i] = 'деловой'
    elif text in publ:
        df_sp['Type'][i] = 'публицистический'
    elif text in fiction:
        df_sp['Type'][i] = 'художественный'
    elif text in oral: 
        df_sp['Type'][i] = 'разговорный'

# %%
df_sp
# Out:
#                                           Left context     Center  \
# 0                                Е́сть тако́е поня́тие       как
# 1                   Деви́ца Алекса́ндра зде́сь живёт /       Как
# 2                      ле́зет пе́ред дра́кой в ще́ли /       как
# 3                                Вы́ бы́ли для меня́ /       как
# 4                         Ка́к зва́ть тебя́ / де́вица?       Как
# ..                                                 ...        ...
# 761                      без тренировок / это ж смерти   подобно
# 762                              Паде́ние его́ сме́рти   подобно
# 763  пери́ода / а Ма́йкова засо́хшего / смо́рщившег...   подобно
# 764  сра́внивали / како́е коли́чество уча́стников п...   подобно
# 765      что́ большинство́ систе́м выбира́ет разме́тку   подобно
#
#                                          Right context Created  \
# 0    по́иски внеземны́х цивилиза́ций"― э́то вро́де бы     2010
# ...

# %%
def no_acentos(text):
    new_text = str()
    for character in text:
        if character == "́":
            continue
        new_text+=character
    return new_text

# %%
for i, text in enumerate(df_sp['Center']):
    if "́" in text:
        df_sp['Center'][i] = no_acentos(text)

# %%
for i, text in enumerate(df_250_wr['Center']):
    df_250_wr['Center'][i] = text.lower()
