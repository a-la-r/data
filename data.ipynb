# %%
from selenium.webdriver.common.keys import Keys
from selenium import webdriver
import time

# %%
driver = webdriver.Chrome("C:\\Users\\User\\Desktop\\r files\\selenium\\chromedriver")

# %%
driver.get("http://www.ruscorpora.ru/new/search-main.html")

# %%
input_lex1 = driver.find_element_by_name("lex1")

# %%
input_gramm1 = driver.find_element_by_name("gramm1")

# %%
input_lex1.send_keys("аки")

# %%
input_gramm1.send_keys("CONJ")

# %%
search_button = driver.find_elements_by_xpath("//html/body/table/tbody/tr[2]/td[2]/table[1]/tbody/tr/td/form[2]/input[15]")[0]

# %%
search_button.click()

# %%
window_after = driver.window_handles[1]
driver.switch_to.window(window_after)

# %%
settings = driver.find_elements_by_xpath("/html/body/div[4]/div[1]/a[3]")[0]
settings
settings.click()
# driver.switch_to.alert
# docs_on_page = driver.find_element_by_name("dpp")
# # time.sleep(10)
# docs_on_page.send_keys("100")
# # settings_button = driver.find_elements_by_xpath('''//*[@id="search-form"]/form/input[21]''')[0]
# # settings_button.click()

# %%
driver.switch_to_alert
# Out:
# <bound method WebDriver.switch_to_alert of <selenium.webdriver.chrome.webdriver.WebDriver (session="f989293ad5125fc7c86119e95ab8d0db")>>

# %%
docs_on_page = driver.find_element_by_name("dpp")
# time.sleep(10)
docs_on_page.send_keys("0")
# settings_button = driver.find_elements_by_xpath('''//*[@id="search-form"]/form/input[21]''')[0]
# settings_button.click()

# %%
settings_button = driver.find_elements_by_xpath('''//*[@id="search-form"]/form/input[21]''')[0]
settings_button.click()

# %%
lis = driver.find_elements_by_tag_name('li')

# %%
for li in lis:
    print(li.text)
# Out:
# И. С. Тургенев. Конец Чертопханова (1872)   [омонимия снята] Все примеры
# Истинно: вы муж ума чудного; просто аки лев! [И. С. Тургенев. Конец Чертопханова (1872)] [омонимия снята] ←…→
# Истинно: вы муж ума чудного; просто аки лев! [И. С. Тургенев. Конец Чертопханова (1872)] [омонимия снята] ←…→
# Сергей Носов. Фигурные скобки (2015)   [омонимия не снята] Все примеры
# Даже если бы я по воде пошел аки посуху, она бы к этому спокойно отнеслась… [Сергей Носов. Фигурные скобки (2015)] [омонимия не снята] ←…→
# Даже если бы я по воде пошел аки посуху, она бы к этому спокойно отнеслась… [Сергей Носов. Фигурные скобки (2015)] [омонимия не снята] ←…→
# коллективный. Блоги // «Русский репортер», 2014   [омонимия не снята] Все примеры
# А когда был на озере Кинерет, то подумал о том, что неплохо бы пройти по воде аки посуху. [коллективный. Блоги // «Русский репортер», 2014] [омонимия не снята] ←…→
# ...

# %%
lo = driver.find_elements_by_tag_name('ol')

# %%
lo[0].text
# Out:
# 'И. С. Тургенев. Конец Чертопханова (1872)   [омонимия снята] Все примеры\nИстинно: вы муж ума чудного; просто аки лев! [И. С. Тургенев. Конец Чертопханова (1872)] [омонимия снята] ←…→\nСергей Носов. Фигурные скобки (2015)   [омонимия не снята] Все примеры\nДаже если бы я по воде пошел аки посуху, она бы к этому спокойно отнеслась… [Сергей Носов. Фигурные скобки (2015)] [омонимия не снята] ←…→\nколлективный. Блоги // «Русский репортер», 2014   [омонимия не снята] Все примеры\nА когда был на озере Кинерет, то подумал о том, что неплохо бы пройти по воде аки посуху. [коллективный. Блоги // «Русский репортер», 2014] [омонимия не снята] ←…→\nАлина Бериашвили. Да здравствует дело Коркодела (2013.05.26) // «Новгородские ведомости», 2013   [омонимия не снята] Все примеры\nФеодор припустил наутек и добрался до Торговой стороны по водам Волхова, аки посуху. [Алина Бериашвили. Да здравствует дело Коркодела (2013.05.26) // «Новгородские ведомости», 2013] [омонимия не снята] ←…→\nГеннадий Рявкин
# ...
